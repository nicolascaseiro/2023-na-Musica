# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/nicolascaseiro/2023-na-Musica/refs/heads/main/2023%20na%20M%C3%BAsica.csv", encoding='utf-8')

df.head()
# Out:
#    #              Música                   Artista  Popularidade  BPM  \
# 0  1             vampire            Olivia Rodrigo            87  137
# 1  2                 A&W              Lana Del Rey            68  157
# 2  3     Dancing Circles                    Sampha            48  106
# 3  4  Boy's a liar Pt. 2  PinkPantheress,Ice Spice            76  133
# 4  5           Moonlight                Kali Uchis            82  137
#
#             Gêneros                                              Álbum  \
# 0               pop                                               GUTS
# 1               pop  Did you know that there's a tunnel under Ocean...
# 2   indie soul, pop                                              Lahai
# 3  bedroom pop, pop                                       Heaven knows
# 4               pop                                  Red Moon In Venus
#
#   Data do Álbum Duração  Duração_segundos  ...  Fala  Ao Vivo  Volume (Db)  \
# 0    2023-09-08   03:39               219  ...     0       20           -6
# 1    2023-03-24   07:13               433  ...    10       10          -15
# 2    2023-10-20   03:53               233  ...     0        0          -12
# 3    2023-11-10   02:11               131  ...     0       20           -8
# 4    2023-03-03   03:07               187  ...     0       20           -7
#
#            Tom  Compasso  Adicionado em        Spotify Track Id  Camelot  \
# 0      F Major         4     2026-07-16  1kuGVB7EU95pJObxwvfwKS       7B
# 1  A#/B♭ Major         4     2026-07-16  5nW4z3pfZgJAJ2QTCz9AIE       6B
# 2      G Minor         3     2026-07-16  6lNyT8TfnpMTRrmJRQKQC9       6A
# 3      F Major         4     2026-07-16  5CCr8msaN3MhgqBoa9yWhH       7B
# 4      G Minor         4     2026-07-16  0JmnkIqdlnUzPaf8sqBRs3       6A
#
#            ISRC  Explícito
# 0  USUG12304091        yes
# 1  GBUM72206757        yes
# 2  UK7MC2200179         no
# 3  GBAYE2300015        yes
# 4  USUM72219486         no
#
# [5 rows x 25 columns]

# %%
linhas, colunas = df.shape[0], df.shape[1]

print(f'Linhas: {linhas}')
print(f'Colunas: {colunas}')
# Out:
# Linhas: 200
# Colunas: 25

# %%
df.describe()
# Out:
#                 #  Popularidade        BPM  Duração_segundos  Dançabilidade  \
# count  200.000000    200.000000  200.00000        200.000000     200.000000
# mean   100.500000     59.360000  125.06000        207.265000      66.000000
# std     57.879185     15.943695   26.09196         77.142267      17.524427
# min      1.000000     14.000000   58.00000         69.000000      10.000000
# 25%     50.750000     49.000000  107.50000        168.750000      56.750000
# 50%    100.500000     60.000000  127.50000        190.000000      70.000000
# 75%    150.250000     70.000000  140.50000        225.500000      79.000000
# max    200.000000     90.000000  204.00000        641.000000      94.000000
#
#           Energia    Acústica  Instrumentalidade    Valência       Fala  \
# count  200.000000  200.000000         200.000000  200.000000  200.00000
# mean    67.015000   25.405000           1.345000   52.430000    7.95000
# std     17.607809   23.973834           7.675974   23.010924   12.08419
# min     24.000000    0.000000           0.000000    4.000000    0.00000
# 25%     55.000000    5.750000           0.000000   34.750000    0.00000
# 50%     68.000000   18.500000           0.000000   53.000000    0.00000
# 75%     81.000000   41.000000           0.000000   70.000000   10.00000
# max     99.000000   89.000000          90.000000   96.000000   50.00000
#
#           Ao Vivo  Volume (Db)    Compasso
# count  200.000000   200.000000  200.000000
# mean    18.950000    -6.180000    3.960000
# std     19.808061     2.440776    0.411395
# min      0.000000   -15.000000    1.000000
# 25%     10.000000    -8.000000    4.000000
# 50%     10.000000    -6.000000    4.000000
# 75%     30.000000    -4.750000    4.000000
# max     90.000000    -1.000000    5.000000

# %%
df.corr(numeric_only=True)
# Out:
#                           #  Popularidade       BPM  Duração_segundos  \
# #                  1.000000      0.016211  0.081783         -0.216896
# Popularidade       0.016211      1.000000  0.092489         -0.093203
# BPM                0.081783      0.092489  1.000000          0.004823
# Duração_segundos  -0.216896     -0.093203  0.004823          1.000000
# Dançabilidade      0.275295      0.104332 -0.040817         -0.412062
# Energia            0.066041     -0.138207  0.205587          0.014337
# Acústica           0.068535      0.041029 -0.103606         -0.169531
# Instrumentalidade -0.111586     -0.153847  0.035775          0.369553
# Valência           0.245685      0.027121 -0.040485         -0.308256
# Fala               0.058160     -0.181332 -0.025905          0.071957
# Ao Vivo            0.147733     -0.044623  0.040667         -0.025074
# Volume (Db)        0.143778      0.013166  0.139519         -0.061930
# Compasso           0.044952     -0.148720 -0.069061          0.061614
#
#                    Dançabilidade   Energia  Acústica  Instrumentalidade  \
# #                       0.275295  0.066041  0.068535          -0.111586
# Popularidade            0.104332 -0.138207  0.041029          -0.153847
# BPM                    -0.040817  0.205587 -0.103606           0.035775
# Duração_segundos       -0.412062  0.014337 -0.169531           0.369553
# Dançabilidade           1.000000 -0.097419 -0.047652          -0.285331
# Energia                -0.097419  1.000000 -0.453580           0.060304
# Acústica               -0.047652 -0.453580  1.000000          -0.053329
# Instrumentalidade      -0.285331  0.060304 -0.053329           1.000000
# Valência                0.536815  0.120474  0.050220          -0.286139
# Fala                    0.052442 -0.074248  0.030807          -0.027551
# Ao Vivo                -0.126524  0.215443  0.011376          -0.065689
# Volume (Db)             0.009516  0.745354 -0.414741          -0.094031
# Compasso               -0.009758  0.040319 -0.060000           0.017122
#
#                    Valência      Fala   Ao Vivo  Volume (Db)  Compasso
# #                  0.245685  0.058160  0.147733     0.143778  0.044952
# Popularidade       0.027121 -0.181332 -0.044623     0.013166 -0.148720
# BPM               -0.040485 -0.025905  0.040667     0.139519 -0.069061
# Duração_segundos  -0.308256  0.071957 -0.025074    -0.061930  0.061614
# Dançabilidade      0.536815  0.052442 -0.126524     0.009516 -0.009758
# Energia            0.120474 -0.074248  0.215443     0.745354  0.040319
# Acústica           0.050220  0.030807  0.011376    -0.414741 -0.060000
# Instrumentalidade -0.286139 -0.027551 -0.065689    -0.094031  0.017122
# Valência           1.000000  0.060834  0.053804     0.146597 -0.016753
# Fala               0.060834  1.000000 -0.065721    -0.116501  0.044071
# Ao Vivo            0.053804 -0.065721  1.000000     0.187318 -0.011347
# Volume (Db)        0.146597 -0.116501  0.187318     1.000000 -0.007206
# Compasso          -0.016753  0.044071 -0.011347    -0.007206  1.000000

# %%
colunas_numericas = df.select_dtypes(include=['number']).columns

outliers_bool = pd.DataFrame(False, index=df.index, columns=colunas_numericas)

for col in colunas_numericas:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    limite_inferior = Q1 - 1.5 * IQR
    limite_superior = Q3 + 1.5 * IQR

    outliers_bool[col] = (df[col] < limite_inferior) | (df[col] > limite_superior)

linhas_com_outliers = outliers_bool.any(axis=1)

df_outliers = df[linhas_com_outliers]

print(f"Total de linhas com pelo menos um outlier: {df_outliers.shape[0]}")
# Out:
# Total de linhas com pelo menos um outlier: 73

# %%
def tempo_para_segundos(tempo_str):
    try:
        minutos, segundos = tempo_str.split(':')
        return int(minutos) * 60 + int(segundos)
    except:
        return None

df['Duração_segundos'] = df['Duração'].apply(tempo_para_segundos)

df['Duração_segundos'] = pd.to_numeric(df['Duração_segundos'], errors='coerce')

duracao_numerica = df['Duração_segundos'].dropna()
Q1 = duracao_numerica.quantile(0.25)
Q3 = duracao_numerica.quantile(0.75)
IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

outliers = df[(df['Duração_segundos'] < limite_inferior) | (df['Duração_segundos'] > limite_superior)]

print(f"Número de outliers na duração: {outliers.shape[0]}\n")

print(outliers[['Música', 'Artista', 'Duração']])
# Out:
# Número de outliers na duração: 14
#
#                                          Música  \
# 1                                           A&W
# 19   why does the earth give us people to love?
# 30                          the BLACK seminole.
# 51     Sweet Sounds Of Heaven (feat. Lady Gaga)
# 52                                       Cosmic
# 53                                   72 Seasons
# 55                                  The Teacher
# 57                           Meeting The Master
# 62                                 Djennaration
# 66                                The Summoning
# 95                                  Calma Amiga
# 125                                   Best Time
# 169                                Melhor Assim
# 187                                  Let's Go 4
#
#                                                Artista Duração
# 1                                         Lana Del Rey   07:13
# 19                                        Kara Jackson   06:15
# 30                             Lil Yachty,Diana Gordon   06:51
# 51                        The Rolling Stones,Lady Gaga   07:22
# 52                                   Avenged Sevenfold   07:31
# 53                                           Metallica   07:39
# 55                                        Foo Fighters   10:04
# 57                                     Greta Van Fleet   05:12
# 62                                             Liturgy   08:20
# 66                                         Sleep Token   06:35
# 95   Pabllo Vittar,Anitta,DJ RaMeMes (O DESTRUIDOR ...   01:09
# 125                                       Brent Faiyaz   01:22
# 169               Cesar Mc,Noventa,Dudu,Felipe Artioli   05:53
# 187  Dj GBR,Mc IG,MC Ryan SP,MC PH,Mc Davi,Mc Luki,...   10:41

# %%
colunas = list(df.columns)

colunas.remove('Duração_segundos')

idx = colunas.index('Duração')

colunas.insert(idx + 1, 'Duração_segundos')

df = df[colunas]

media_duracao = df['Duração_segundos'].mean()
minutos = int(media_duracao // 60)
segundos = int(media_duracao % 60)
print(f"Média da duração das músicas: {minutos} min {segundos} seg")
# Out:
# Média da duração das músicas: 3 min 27 seg

# %%
df['BPM'] = pd.to_numeric(df['BPM'], errors='coerce')

bpm_validos = df['BPM'].dropna()

Q1 = bpm_validos.quantile(0.25)
Q3 = bpm_validos.quantile(0.75)
IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

outliers_bpm = df[(df['BPM'] < limite_inferior) | (df['BPM'] > limite_superior)]

print(f"Número de outliers de BPM: {outliers_bpm.shape[0]}")
display(outliers_bpm[['Música', 'Artista', 'BPM']])
# Out:
# Número de outliers de BPM: 1
#         Música        Artista  BPM
# 22  Last Night  Morgan Wallen  204

# %%
media_bpm = df['BPM'].mean()
print(f"Média do BPM: {media_bpm:.2f}")
# Out:
# Média do BPM: 125.06

# %%
df_generos = df.dropna(subset=['Gêneros'])
df_generos['Gêneros_lista'] = df_generos['Gêneros'].apply(lambda x: [g.strip() for g in x.split(',')])
df_exploded = df_generos.explode('Gêneros_lista')

df_exploded.groupby('Gêneros_lista')['Popularidade'].mean().sort_values(ascending=False).head(10)
# Out:
# Gêneros_lista
# jazz              89.000000
# red dirt          88.000000
# reggaeton         85.500000
# urbano latino     83.333333
# trap latino       83.000000
# country           82.750000
# pop latino        81.500000
# trap argentino    79.000000
# sierreño          78.000000
# dance pop         77.000000
# Name: Popularidade, dtype: float64

# %%
df.sort_values(by='Popularidade', ascending=False)[['Música', 'Artista', 'Popularidade']].head(10)
# Out:
#                                             Música  \
# 140                                   Lose Control
# 5                                          Flowers
# 15                                  From The Start
# 73                           My Love Mine All Mine
# 129                                         greedy
# 145  I Remember Everything (feat. Kacey Musgraves)
# 13                                          MONACO
# 0                                          vampire
# 22                                      Last Night
# 26                      FE!N (feat. Playboi Carti)
#
#                         Artista  Popularidade
# 140                 Teddy Swims            90
# 5                   Miley Cyrus            89
# 15                       Laufey            89
# 73                       Mitski            88
# 129                  Tate McRae            88
# 145  Zach Bryan,Kacey Musgraves            88
# 13                    Bad Bunny            87
# 0                Olivia Rodrigo            87
# 22                Morgan Wallen            87
# 26   Travis Scott,Playboi Carti            86

# %%
df.sort_values(by='Dançabilidade', ascending=False)[['Música', 'Artista', 'Dançabilidade']].head(10)
# Out:
#                                        Música  \
# 158                      VAMPIRO DE MADUREIRA
# 115                               Lovin On Me
# 159                         Posturado E Calmo
# 113                                  Sprinter
# 154           Faz um Vuk Vuk (Teto Espelhado)
# 172                             Sem Compaixão
# 96                               QUÍMICO AMOR
# 83                               99 Problemas
# 180  Fantástico Mundo da Oakley - Bonus Track
# 157                      Vai Novinha Ah Ah Ah
#
#                                          Artista  Dançabilidade
# 158                           Mc Carol,Mc Gorila             94
# 115                                  Jack Harlow             94
# 159                                  Léo Santana             93
# 113                             Dave,Central Cee             92
# 154  MC Kevin o Chris,Dj Nk Da Serra,Mc Magrinho             92
# 172                         Leviano,MC Cabelinho             92
# 96                  FBC,Pedro Senna,Ugo Ludovico             91
# 83                 Duquesa,Mc Luanna,Go Dassisti             91
# 180                                   Kyan,Mu540             91
# 157                                  Dyamante DJ             91

# %%
df.sort_values(by='Energia', ascending=False)[['Música', 'Artista', 'Energia']].head(10)
# Out:
#                           Música                      Artista  Energia
# 64                Bogus Operandi                    The Hives       99
# 60            MORE THAN YOU KNOW                    blink-182       99
# 72                 Rabid Funeral                      Autopsy       99
# 53                    72 Seasons                    Metallica       98
# 62                  Djennaration                      Liturgy       97
# 70             Jesus He Knows Me                        Ghost       96
# 94          MEIO TERMO - Ao Vivo                 Luan Santana       96
# 32   Never Die (feat. Lil Wayne)                Nas,Lil Wayne       96
# 153                        Tá OK      DENNIS,MC Kevin o Chris       96
# 150                 Joga Pra Lua  Anitta,DENNIS,PEDRO SAMPAIO       95

# %%
df.sort_values(by='Valência', ascending=False)[['Música', 'Artista', 'Valência']].head(10)
# Out:
#                          Música  \
# 8                    HOT TO GO!
# 96                 QUÍMICO AMOR
# 82                        DAMN!
# 59   GOSSIP (feat. Tom Morello)
# 192         Canudinho - Ao Vivo
# 132                       Cupid
# 68                 I See Myself
# 84                       DJAVAN
# 89     No Tempo da Intolerância
# 112  Who Told You (feat. Drake)
#
#                                                Artista  Valência
# 8                                        Chappell Roan        96
# 96                        FBC,Pedro Senna,Ugo Ludovico        96
# 82   Ryu, The Runner,Emitê Único,Salve Crazy,Luk Th...        92
# 59                                Måneskin,Tom Morello        91
# 192                          Gusttavo Lima,Ana Castela        91
# 132                                        FIFTY FIFTY        91
# 68                                               Geese        89
# 84                          Luccas Carlos,Maui,Francci        89
# 89                                         Elza Soares        88
# 112                                        J Hus,Drake        88

# %%
df.sort_values(by='Volume (Db)', ascending=False)[['Música', 'Artista', 'Volume (Db)']].head(10)
# Out:
#                                                 Música  \
# 28                                            Burfict!
# 153                                              Tá OK
# 64                                      Bogus Operandi
# 12                                                 TQG
# 60                                  MORE THAN YOU KNOW
# 26                          FE!N (feat. Playboi Carti)
# 59                          GOSSIP (feat. Tom Morello)
# 32                         Never Die (feat. Lil Wayne)
# 196                                   Daqui pra Sempre
# 143  AmEN! (feat. Lil Uzi Vert and Daryl Palumbo of...
#
#                                                Artista  Volume (Db)
# 28                               JPEGMAFIA,Danny Brown           -1
# 153                            DENNIS,MC Kevin o Chris           -1
# 64                                           The Hives           -2
# 12                                     KAROL G,Shakira           -3
# 60                                           blink-182           -3
# 26                          Travis Scott,Playboi Carti           -3
# 59                                Måneskin,Tom Morello           -3
# 32                                       Nas,Lil Wayne           -3
# 196                                 Manu,Simone Mendes           -3
# 143  Bring Me The Horizon,Lil Uzi Vert,Daryl Palumb...           -3

# %%
import seaborn as sns
import matplotlib.pyplot as plt

generos_temp = df['Gêneros'].dropna().apply(lambda x: [g.strip() for g in x.split(',')])
df_temp = df.loc[generos_temp.index].copy()
df_temp['genero'] = generos_temp
df_temp = df_temp.explode('genero')

contagem_generos = df_temp['genero'].value_counts()

plt.figure(figsize=(10,6))
contagem_generos.head(10).plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Top 10 Gêneros Musicais')
plt.ylabel('Quantidade de Músicas')
plt.xlabel('Gêneros')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.ticker as ticker

def formatar_tempo(segundos, pos=None):
    minutos = int(segundos) // 60
    seg = int(segundos) % 60
    return f'{minutos}:{seg:02d}'

plt.figure(figsize=(10, 6))
plt.hist(df['Duração_segundos'].dropna(), bins=30, color='skyblue', edgecolor='black')
plt.title('Distribuição da Duração das Músicas')
plt.xlabel('Duração (min:seg)')
plt.ylabel('Número de Músicas')

ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.FuncFormatter(formatar_tempo))

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.boxplot(df['Duração_segundos'].dropna(), vert=False)
plt.title('Boxplot da Duração das Músicas')
plt.xlabel('Duração (min:seg)')

ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.FuncFormatter(formatar_tempo))

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlação entre variáveis numéricas')
plt.show()

# %%
meses_pt = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho',
            'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro']

df_temp_mes = df.copy()
df_temp_mes['Data do Álbum'] = pd.to_datetime(df_temp_mes['Data do Álbum'], errors='coerce')  # <-- alterado aqui
df_temp_mes['Mês'] = df_temp_mes['Data do Álbum'].dt.month                                     # <-- alterado aqui

popularidade_por_mes = df_temp_mes.groupby('Mês')['Popularidade'].mean()

plt.figure(figsize=(12,6))
popularidade_por_mes.plot(marker='o')
plt.title('Popularidade Média das Músicas por Mês de Lançamento')
plt.xlabel('Mês')
plt.ylabel('Popularidade Média')
plt.grid(True)
plt.xticks(ticks=range(1, 13), labels=meses_pt, rotation=45)
plt.tight_layout()
plt.show()

# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.12/dist-packages (1.60.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.4.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit) (3.1.51)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (26.2)
# Requirement already satisfied: pandas<4,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<13,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (11.3.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.9.3)
# Requirement already satisfied: protobuf<8,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.29.6)
# Requirement already satisfied: pyarrow<25,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (4.16.0)
# Requirement already satisfied: starlette<2,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (1.3.1)
# Requirement already satisfied: uvicorn<1,>=0.30.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.51.0)
# Requirement already satisfied: httptools<1,>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.8.0)
# Requirement already satisfied: anyio<5,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (4.14.2)
# Requirement already satisfied: python-multipart<1,>=0.0.10 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.0.32)
# Requirement already satisfied: websockets<17,>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (15.0.1)
# Requirement already satisfied: itsdangerous<3,>=2.1.2 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.2.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.24.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=4.0.0->streamlit) (3.18)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<4,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4,>=1.4.0->streamlit) (2026.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2026.6.17)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn<1,>=0.30.0->streamlit) (0.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2026.6.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import plotly.express as px

st.set_page_config(page_title="Dashboard 2023 na Música", layout="wide")

def carregar_dados():
    url = "https://raw.githubusercontent.com/nicolascaseiro/2023-na-Musica/refs/heads/main/2023%20na%20M%C3%BAsica.csv"
    df = pd.read_csv(url, encoding='utf-8')
    return df

df = carregar_dados()

generos_lista = df['Gêneros'].dropna().apply(lambda x: [g.strip() for g in x.split(',')])
artistas_lista = df['Artista'].dropna().apply(lambda x: [a.strip() for a in x.split(',')])

df_temp = df.copy()
df_temp = df_temp.loc[generos_lista.index]
df_temp = df_temp.assign(Gêneros_lista=generos_lista)
df_temp = df_temp.explode('Gêneros_lista')

artistas_lista_temp = artistas_lista.loc[df_temp.index]
df_temp = df_temp.assign(Artistas_lista=artistas_lista_temp)
df_temp = df_temp.explode('Artistas_lista')

meses_pt = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho',
            'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro']

df_temp['Data do Álbum'] = pd.to_datetime(df_temp['Data do Álbum'], errors='coerce')
df_temp['Mês'] = df_temp['Data do Álbum'].dt.month.apply(lambda x: meses_pt[x-1] if pd.notna(x) else None)

st.sidebar.header("Filtros")

def ordenar_meses(meses_selecionados):
    return sorted(meses_selecionados, key=lambda m: meses_pt.index(m))

meses_disponiveis = ordenar_meses(df_temp['Mês'].dropna().unique())
generos_disponiveis = sorted(df_temp['Gêneros_lista'].dropna().unique())
artistas_disponiveis = sorted(df_temp['Artistas_lista'].dropna().unique())

mes_selecionado = st.sidebar.multiselect('Filtrar por Mês:', meses_disponiveis)
genero_selecionado = st.sidebar.multiselect('Filtrar por Gênero:', generos_disponiveis)
artista_selecionado = st.sidebar.multiselect('Filtrar por Artista:', artistas_disponiveis)

df_filtrado = df_temp.copy()

if mes_selecionado:
    df_filtrado = df_filtrado[df_filtrado['Mês'].isin(mes_selecionado)]

if genero_selecionado:
    df_filtrado = df_filtrado[df_filtrado['Gêneros_lista'].isin(genero_selecionado)]

if artista_selecionado:
    df_filtrado = df_filtrado[df_filtrado['Artistas_lista'].isin(artista_selecionado)]

indices_filtrados = df_filtrado.index.unique()
df_tabela = df.loc[indices_filtrados].copy()
df_tabela['Data do Álbum'] = pd.to_datetime(df_tabela['Data do Álbum'], errors='coerce')
df_tabela['Mês'] = df_tabela['Data do Álbum'].dt.month.apply(lambda x: meses_pt[x-1] if pd.notna(x) else None)
total_musicas_filtradas = df_tabela['Música'].nunique()

st.title("Dashboard 2023 na Música")

col1, col2, col3, col4 = st.columns(4)
col1.metric("Total de músicas", total_musicas_filtradas)
col2.metric("Média Popularidade", f"{df_filtrado['Popularidade'].mean():.2f}")
col3.metric("Total de Artistas", df_filtrado['Artistas_lista'].nunique())
col4.metric("Total de Gêneros", df_filtrado['Gêneros_lista'].nunique())

st.markdown("---")

df_grafico = df_filtrado.groupby('Gêneros_lista')['Popularidade'].mean().reset_index()

fig = px.bar(df_grafico,
             x='Gêneros_lista',
             y='Popularidade',
             title='Popularidade Média por Gênero Musical (2024)',
             labels={'Gêneros_lista': 'Gênero', 'Popularidade': 'Popularidade Média'},
             color='Popularidade',
             color_continuous_scale='Viridis',
             text=df_grafico['Popularidade'].round(2)
            )

fig.update_traces(textposition='outside', marker_line_width=1.5, marker_line_color='black')
fig.update_layout(
    plot_bgcolor='white',
    title_font=dict(size=24, family='Verdana', color='darkblue'),
    xaxis_title_font=dict(size=18, family='Verdana'),
    yaxis_title_font=dict(size=18, family='Verdana'),
    xaxis_tickangle=-45,
    xaxis_tickfont=dict(size=12, family='Verdana'),
    yaxis=dict(range=[0, 100]),
    margin=dict(l=40, r=40, t=80, b=100)
)

st.plotly_chart(fig, use_container_width=True)

st.markdown("---")

colunas_exibir = ['Música', 'Artista', 'Gêneros', 'Popularidade', 'Mês']
st.dataframe(df_tabela[colunas_exibir])
# Out:
# Overwriting app.py

# %%
df.head(200)
# Out:
#        #                             Música                   Artista  \
# 0      1                            vampire            Olivia Rodrigo
# 1      2                                A&W              Lana Del Rey
# 2      3                    Dancing Circles                    Sampha
# 3      4                 Boy's a liar Pt. 2  PinkPantheress,Ice Spice
# 4      5                          Moonlight                Kali Uchis
# ..   ...                                ...                       ...
# 195  196             Erro Gostoso - Ao Vivo             Simone Mendes
# 196  197                   Daqui pra Sempre        Manu,Simone Mendes
# 197  198                 Oi Balde - Ao Vivo       Zé Neto & Cristiano
# 198  199  Traumatizei (Ao Vivo Em Brasília)        Henrique & Juliano
# 199  200                     Será - Ao Vivo          Maiara & Maraisa
#
#      Popularidade  BPM                                            Gêneros  \
# 0              87  137                                                pop
# 1              68  157                                                pop
# 2              48  106                                    indie soul, pop
# 3              76  133                                   bedroom pop, pop
# 4              82  137                                                pop
# ..            ...  ...                                                ...
# 195            65  154  sertanejo, sertanejo universitário, pagode, pi...
# 196            64  160  tecnobrega, brega, sertanejo, forró, piseiro, ...
# 197            72  108  sertanejo, sertanejo universitário, agronejo, ...
# 198            75  166  sertanejo, sertanejo universitário, arrocha, a...
# 199            29  148        sertanejo, sertanejo universitário, piseiro
#
#                                                  Álbum Data do Álbum Duração  \
# 0                                                 GUTS    2023-09-08   03:39
# 1    Did you know that there's a tunnel under Ocean...    2023-03-24   07:13
# 2                                                Lahai    2023-10-20   03:53
# 3                                         Heaven knows    2023-11-10   02:11
# 4                                    Red Moon In Venus    2023-03-03   03:07
# ..                                                 ...           ...     ...
# 195                               Cintilante (Ao Vivo)    2023-01-27   02:58
# 196                                   Daqui pra Sempre    2023-09-22   03:22
# 197                                 Escolhas (Ao Vivo)    2023-10-05   02:39
# 198                        To Be (Ao Vivo Em Brasília)    2023-07-28   02:52
# 199                               Identidade (Ao Vivo)    2023-03-23   02:48
#
#      Duração_segundos  ...  Fala  Ao Vivo  Volume (Db)          Tom  Compasso  \
# 0                 219  ...     0       20           -6      F Major         4
# 1                 433  ...    10       10          -15  A#/B♭ Major         4
# 2                 233  ...     0        0          -12      G Minor         3
# 3                 131  ...     0       20           -8      F Major         4
# 4                 187  ...     0       20           -7      G Minor         4
# ..                ...  ...   ...      ...          ...          ...       ...
# 195               178  ...     0       80           -3  F#/G♭ Major         4
# 196               202  ...     0       90           -3      G Minor         4
# 197               159  ...     0       80           -6      D Major         4
# 198               172  ...     0       40           -3      B Major         4
# 199               168  ...     0       90           -3      F Major         4
#
#      Adicionado em        Spotify Track Id  Camelot          ISRC  Explícito
# 0       2026-07-16  1kuGVB7EU95pJObxwvfwKS       7B  USUG12304091        yes
# 1       2026-07-16  5nW4z3pfZgJAJ2QTCz9AIE       6B  GBUM72206757        yes
# 2       2026-07-16  6lNyT8TfnpMTRrmJRQKQC9       6A  UK7MC2200179         no
# 3       2026-07-16  5CCr8msaN3MhgqBoa9yWhH       7B  GBAYE2300015        yes
# 4       2026-07-16  0JmnkIqdlnUzPaf8sqBRs3       6A  USUM72219486         no
# ..             ...                     ...      ...           ...        ...
# 195     2026-07-21  51pxwIxDVCbFHW8oyJFQXD       2B  BRUM72202346         no
# 196     2026-07-21  35D06z7kmwMmYYbyJ0BkSm       6A  QZTPX2351515         no
# 197     2026-07-21  2XmPCfvLakXAbSj2qgxskV      10B  BRRGE2300213         no
# 198     2026-07-21  5JO5wfblhyRi2S5G4mNv56       1B  BCVDD2200002         no
# 199     2026-07-21  4CDqMCAb0WuPhDjzRo1oqY       7B  BRWNV2200159         no
#
# [200 rows x 25 columns]
